# %%
import pandas as pd

# %%
matches = pd.read_csv("final_data.csv", index_col = 0)

# %%
matches.head()
# Out:
#                   date   time            comp        round  day venue result  \
# Unnamed: 0
# 0           2024-08-17  12:30  Premier League  Matchweek 1  Sat  Away      W
# 1           2024-08-25  16:30  Premier League  Matchweek 2  Sun  Home      W
# 2           2024-09-01  16:00  Premier League  Matchweek 3  Sun  Away      W
# 3           2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      L
# 5           2024-09-21  15:00  Premier League  Matchweek 5  Sat  Home      W
#
#              gf   ga         opponent  ...  match report  notes    sh   sot  \
# Unnamed: 0                             ...
# 0           2.0  0.0     Ipswich Town  ...  Match Report    NaN  18.0   5.0
# 1           2.0  0.0        Brentford  ...  Match Report    NaN  19.0   8.0
# 2           3.0  0.0   Manchester Utd  ...  Match Report    NaN  11.0   3.0
# 3           0.0  1.0  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0
# ...

# %%
matches.shape
# Out:
# (5756, 28)

# %%
matches.index = range(matches.shape[0])

# %%
matches
# Out:
#             date   time            comp         round  day venue result   gf  \
# 0     2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1     2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2     2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3     2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4     2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...          ...    ...             ...           ...  ...   ...    ...  ...
# 5751  2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752  2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753  2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754  2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755  2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
matches["team"].value_counts()
# Out:
# Crystal Palace              288
# Arsenal                     288
# Manchester City             288
# Newcastle United            288
# Tottenham Hotspur           288
# West Ham United             288
# Manchester United           288
# Brighton and Hove Albion    288
# Liverpool                   287
# Everton                     287
# Chelsea                     287
# Leicester City              250
# Southampton                 250
# Wolverhampton Wanderers     249
# Burnley                     228
# Aston Villa                 212
# Bournemouth                 212
# Fulham                      174
# Watford                     152
# Brentford                   136
# Sheffield United            114
# Leeds United                114
# Nottingham Forest            98
# Huddersfield Town            76
# Norwich City                 76
# West Bromwich Albion         76
# Swansea City                 38
# Luton Town                   38
# Cardiff City                 38
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     160
# Matchweek 12    160
# Matchweek 2     160
# Matchweek 20    160
# Matchweek 19    160
# Matchweek 18    160
# Matchweek 17    160
# Matchweek 16    160
# Matchweek 14    160
# Matchweek 13    160
# Matchweek 21    160
# Matchweek 11    160
# Matchweek 9     160
# Matchweek 8     160
# Matchweek 7     160
# Matchweek 6     160
# Matchweek 5     160
# Matchweek 4     160
# Matchweek 3     160
# Matchweek 10    160
# Matchweek 15    158
# Matchweek 22    158
# Matchweek 34    140
# Matchweek 37    140
# Matchweek 32    140
# Matchweek 36    140
# Matchweek 35    140
# Matchweek 29    140
# Matchweek 33    140
# Matchweek 25    140
# Matchweek 31    140
# Matchweek 30    140
# Matchweek 28    140
# Matchweek 27    140
# Matchweek 26    140
# Matchweek 24    140
# Matchweek 23    140
# Matchweek 38    140
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
matches["target"] = (matches["result"]=="W").astype("int")

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 150, min_samples_split = 10, random_state=1)

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'notes', 'sh', 'sot',
#        'dist', 'fk', 'pk', 'pkatt', 'season', 'team', 'venue_code', 'opp_code',
#        'hour', 'day_code', 'target'],
#       dtype='object')

# %%
matches["team_code"] = matches["team"].astype("category").cat.codes

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
predictors = ["venue_code", "opp_code","team_code","xg", "xga"]

# %%
train = matches[matches["date"]<"2024-01-01"]

# %%
test = matches[matches["date"]>="2024-01-01"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=150, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.7437810945273632

# %%
matches
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 5751 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W  1.0
# 5752 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D  2.0
# 5753 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W  1.0
# 5754 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W  1.0
# 5755 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L  0.0
#
# ...

# %%
precision = precision_score(test["target"], preds)

# %%
precision
# Out:
# 0.6744186046511628

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(test["target"], preds)
cm
# Out:
# array([[424,  84],
#        [122, 174]], dtype=int64)

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = "left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#            date   time            comp         round  day venue result   gf  \
# 4999 2017-09-09  12:30  Premier League   Matchweek 4  Sat  Home      W  5.0
# 5000 2017-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  6.0
# 5001 2017-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  5.0
# 5002 2017-09-30  17:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 5003 2017-10-14  15:00  Premier League   Matchweek 8  Sat  Home      W  7.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 82   2024-12-26  12:30  Premier League  Matchweek 18  Thu  Home      D  1.0
# 83   2024-12-29  14:30  Premier League  Matchweek 19  Sun  Away      W  2.0
# 84   2025-01-04  15:00  Premier League  Matchweek 20  Sat  Home      W  4.0
# 85   2025-01-14  19:30  Premier League  Matchweek 21  Tue  Away      D  2.0
# 86   2025-01-19  16:30  Premier League  Matchweek 22  Sun  Away      W  6.0
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                    date   time            comp         round  \
# team
# Arsenal                 5189 2017-09-09  15:00  Premier League   Matchweek 4
#                         5190 2017-09-17  13:30  Premier League   Matchweek 5
#                         5191 2017-09-25  20:00  Premier League   Matchweek 6
#                         5192 2017-10-01  12:00  Premier League   Matchweek 7
#                         5193 2017-10-14  17:30  Premier League   Matchweek 8
# ...                                 ...    ...             ...           ...
# Wolverhampton Wanderers 365  2024-12-22  14:00  Premier League  Matchweek 17
#                         366  2024-12-26  17:30  Premier League  Matchweek 18
#                         367  2024-12-29  15:00  Premier League  Matchweek 19
#                         368  2025-01-06  20:00  Premier League  Matchweek 20
#                         369  2025-01-15  19:30  Premier League  Matchweek 21
#
# ...

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 5189 2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W  3.0
# 5190 2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D  0.0
# 5191 2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W  2.0
# 5192 2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W  2.0
# 5193 2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L  1.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 365  2024-12-22  14:00  Premier League  Matchweek 17  Sun  Away      W  3.0
# 366  2024-12-26  17:30  Premier League  Matchweek 18  Thu  Home      W  2.0
# 367  2024-12-29  15:00  Premier League  Matchweek 19  Sun  Away      D  2.0
# 368  2025-01-06  20:00  Premier League  Matchweek 20  Mon  Home      L  0.0
# 369  2025-01-15  19:30  Premier League  Matchweek 21  Wed  Away      L  0.0
#
# ...

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < "2024-01-01"]
    test = data[data["date"] >= "2024-01-01"]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    accuracy = accuracy_score(test["target"], preds)
    precision = precision_score(test["target"], preds)
    return preds, accuracy, precision

# %%
predictors = predictors + new_cols
predictors
# Out:
# ['venue_code',
#  'opp_code',
#  'team_code',
#  'xg',
#  'xga',
#  'gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
preds, accuracy, precision = make_predictions(matches_rolling, predictors)

# %%
accuracy
# Out:
# 0.7490636704119851

# %%
precision
# Out:
# 0.6702508960573477

# %%
# using rolling averages not making that much of a difference 
# we can use the original predictors
predictors = ["venue_code", "opp_code","team_code","xg", "xga"]
preds, accuracy, precision = make_predictions(matches, predictors)

# %%
accuracy
# Out:
# 0.7437810945273632

# %%
precision
# Out:
# 0.6744186046511628

# %%
import pickle

# %%
pickle.dump(rf, open('model.pkl', 'wb'))

# %%
matches["team_code"].value_counts()
# Out:
# 8     288
# 0     288
# 17    288
# 19    288
# 26    288
# 29    288
# 18    288
# 4     288
# 15    287
# 9     287
# 7     287
# 14    250
# 23    250
# 30    249
# 5     228
# 1     212
# 2     212
# 10    174
# 27    152
# 3     136
# 22    114
# 13    114
# 21     98
# 11     76
# 20     76
# 28     76
# 25     38
# 16     38
# 6      38
# 24     38
# 12     22
# Name: team_code, dtype: int64

# %%
matches["opp_code"].value_counts()
# Out:
# 26    288
# 8     288
# 19    288
# 17    288
# 4     288
# 29    288
# 0     288
# 18    288
# 7     287
# 9     287
# 15    287
# 23    250
# 14    250
# 30    249
# 5     228
# 2     212
# 1     212
# 10    174
# 27    152
# 3     136
# 22    114
# 13    114
# 21     98
# 20     76
# 28     76
# 11     76
# 6      38
# 24     38
# 25     38
# 16     38
# 12     22
# Name: opp_code, dtype: int64

# %%
matches[matches["team_code"]==0].iloc[0]["team"]
# Out:
# 'Arsenal'

# %%
teams_dict = {}
for i in range(31):
    team_name = matches[matches["team_code"]==i].iloc[0]["team"]
    teams_dict[team_name] = i
    
teams_dict
# Out:
# {'Arsenal': 0,
#  'Aston Villa': 1,
#  'Bournemouth': 2,
#  'Brentford': 3,
#  'Brighton and Hove Albion': 4,
#  'Burnley': 5,
#  'Cardiff City': 6,
#  'Chelsea': 7,
#  'Crystal Palace': 8,
#  'Everton': 9,
#  'Fulham': 10,
#  'Huddersfield Town': 11,
#  'Ipswich Town': 12,
#  'Leeds United': 13,
#  'Leicester City': 14,
#  'Liverpool': 15,
#  'Luton Town': 16,
#  'Manchester City': 17,
#  'Manchester United': 18,
#  'Newcastle United': 19,
#  'Norwich City': 20,
#  'Nottingham Forest': 21,
#  'Sheffield United': 22,
#  'Southampton': 23,
#  'Stoke City': 24,
#  'Swansea City': 25,
#  'Tottenham Hotspur': 26,
#  'Watford': 27,
#  'West Bromwich Albion': 28,
#  'West Ham United': 29,
#  'Wolverhampton Wanderers': 30}

# %%
matches["team"].unique()
# Out:
# array(['Liverpool', 'Arsenal', 'Nottingham Forest', 'Manchester City',
#        'Newcastle United', 'Chelsea', 'Bournemouth', 'Aston Villa',
#        'Brighton and Hove Albion', 'Fulham', 'Brentford',
#        'Crystal Palace', 'Manchester United', 'West Ham United',
#        'Tottenham Hotspur', 'Everton', 'Wolverhampton Wanderers',
#        'Ipswich Town', 'Leicester City', 'Southampton', 'Luton Town',
#        'Burnley', 'Sheffield United', 'Leeds United', 'Watford',
#        'Norwich City', 'West Bromwich Albion', 'Cardiff City',
#        'Huddersfield Town', 'Swansea City', 'Stoke City'], dtype=object)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(solver = 'liblinear')

# %%
#lr.fit(train[predictors], train["target"])

# %%
#y_pred = lr.predict(test[predictors])
#accuracy = accuracy_score(test["target"], y_pred)
#accuracy

# %%
#lr.predict_proba(test[predictors])[54]
